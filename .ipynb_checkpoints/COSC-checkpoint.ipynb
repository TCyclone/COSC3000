# %%
#!jupyter nbextension enable --py widgetsnbextension --sys-prefix
#!jupyter serverextension enable voila --sys-prefix
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
# Enabling: voila
# - Writing config: C:\Users\tomwc\anaconda3\etc\jupyter
#     - Validating...
#       voila 0.3.5 ok

# %%
import pydeck as pdk
import pandas as pd
import json
import ipywidgets as widgets
import os
import requests

# BUILDING_LOAD_DATA = "C:/Users/tomwc/OneDrive/Documents/Uni/Year 5 Sem 1/COSC3000/UCSD Microgrid Database/Python Scripts/Data Files/BuildingLoad"
# BUILDING_LOCATION_DATA = "C:/Users/tomwc/OneDrive/Documents/Uni/Year 5 Sem 1/COSC3000/Locations.csv"
BUILDING_LOCATION_DATA = "https://raw.githubusercontent.com/TCyclone/COSC3000/main/Locations.csv"
BUILDING_LOAD_DATA = "https://raw.githubusercontent.com/TCyclone/PowerData/main/"

dfLoad = pd.DataFrame(columns=['Time'])

time = []
start = 2400
for i in range(96):
    if i%4 == 0:
        start = start - 55
        time.append(start)
    else:
        start = start - 15
        time.append(start)
        
dfLoad['Time'] = time

# fLocation = open(BUILDING_LOCATION_DATA)
# fLocation = requests.get(BUILDING_LOCATION_DATA, auth=('user', 'pass'))

# put branch and node results into dataframe
dfLocation = pd.read_csv(BUILDING_LOCATION_DATA)

# f.close()
# print(os.listdir(BUILDING_LOAD_DATA))
files = ['BioEngineeringPV.csv', 'BSB_BuildingPV.csv', 'BSB_LibraryPV.csv', 'CenterHall.csv', 'CSC_BuildingPV.csv', 'CUP_PV.csv', 'EastCampus.csv', 'EBU2_A_PV.csv', 'EBU2_B_PV.csv', 'ElectricShopPV.csv', 'GalbraithHall.csv', 'GarageFleetsPV.csv', 'GeiselLibrary.csv', 'Gilman.csv', 'GilmanParkingPV.csv', 'Hopkins.csv', 'HopkinsParkingPV.csv', 'KeelingA_PV.csv', 'KeelingB_PV.csv', 'KyoceraSkylinePV.csv', 'LeichtagPV.csv', 'Mandeville.csv', 'MayerHallPV.csv', 'MESOM_PV.csv', 'MusicBuilding.csv', 'OslerParkingPV.csv', 'OttersonHall.csv', 'PepperCanyon.csv', 'PoliceDepartment.csv', 'PowellPV.csv', 'PriceCenterA_PV.csv', 'PriceCenterB_PV.csv', 'Processed.csv', 'ProcessedData.csv', 'RadyHall.csv', 'RobinsonHall.csv', 'SDSC_PV.csv', 'SME_SolarPV.csv', 'SocialScience.csv', 'StephenBirchPV.csv', 'StudentServices.csv', 'TradeStreetPV.csv']
for filename in files:#os.listdir(BUILDING_LOAD_DATA):
#     with open(os.path.join(BUILDING_LOAD_DATA, filename), 'r') as f:
    power = []
    i = 0
    df = pd.read_csv(os.path.join(BUILDING_LOAD_DATA, filename))
    for i in range(96):
        power.append(df.at[i,'RealPower'])
    dfLoad[filename] = power

powers = []
coloursR = []
coloursG = []
coloursB = []
for i in range(96):
    for j in dfLocation['Location']:
        powers.append(dfLoad.at[i,j])
#         print (j[-5].isupper(), j[-5], j)
    dfLocation["time_" + str(dfLoad.at[i,'Time'])] = powers
    powers = []
    
for j in dfLocation['Location']:
    if j[-5].islower():
        coloursR.append(255)
        coloursG.append(0)
#         coloursB.append(0)
    else:
        coloursG.append(255)
        coloursR.append(0)
#         coloursB.append(0)
dfLocation["coloursR"] = coloursR
dfLocation["coloursG"] = coloursG
# dfLocation["coloursB"] = coloursB


# display(dfLocation)


import ipywidgets as widgets

timeWid = widgets.IntSlider(
    value=0,
    min=0,
    max=2345,
    step=15,
    description='Time:'
)

caption = widgets.Label(value='OIIII')

def on_value_change(change):
    caption.value = 'Slider now in: ' + (str(change['new']))
    
timeWid.observe(on_value_change, names='value')

display(timeWid, caption)

"""
ColumnLayer
===========

Real estate values for select properties in Taipei. Data is from 2012-2013.
The height of a column indicates increasing price per unit area, and the color indicates distance from a subway stop.

The real estate valuation data set from UC Irvine's Machine Learning repository, viewable here:

https://archive.ics.uci.edu/ml/datasets/Real+estate+valuation+data+set
"""

# view = pdk.data_utils.compute_view(dfLocation[["lng", "lat"]])
view = pdk.ViewState(latitude=32.87788317, longitude=-117.2372732, bearing=45, pitch=50, zoom=15,)

view.pitch = 75
view.bearing = 60

column_layer = pdk.Layer(
    "ColumnLayer",
    data=dfLocation,
    get_position=["lng", "lat"],
    get_elevation="time_1900",
    elevation_scale=1,
    radius=20,
    get_fill_color=["coloursR", "coloursG", "0", 200],
    pickable=True,
    auto_highlight=True,
)

tooltip = {
    "html": "<b>{Location}</b>, load/generation at time : <b>{time_2345}</b> ",
    "style": {"background": "grey", "color": "white", "font-family": '"Helvetica Neue", Arial', "z-index": "10000"},
}

r = pdk.Deck(
    column_layer,
    initial_view_state=view,
    tooltip=tooltip,
    map_provider="mapbox",
    map_style=pdk.map_styles.SATELLITE,
)

# r.show()
r.to_html("column_layer.html")
# Out:
# IntSlider(value=0, description='Time:', max=2345, step=15)
# Label(value='OIIII')
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.4.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-map-container {
#   width: 100%;
#   height: 100%;
#   background-color: black;
# }
#
# #map {
#   pointer-events: none;
#   height: 100%;
#   width: 100%;
#   position: absolute;
#   z-index: 1;
# }
#
# #deckgl-overlay {
#   z-index: 2;
#   background: none;
# }
#
# #deck-map-wrapper {
#   width: 100%;
#   height: 100%;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const jsonInput = {&quot;initialViewState&quot;: {&quot;bearing&quot;: 60, &quot;latitude&quot;: 32.87788317, &quot;longitude&quot;: -117.2372732, &quot;pitch&quot;: 75, &quot;zoom&quot;: 15}, &quot;layers&quot;: [{&quot;@@type&quot;: &quot;ColumnLayer&quot;, &quot;autoHighlight&quot;: true, &quot;data&quot;: [{&quot;Location&quot;: &quot;CenterHall.csv&quot;, &quot;coloursG&quot;: 0, &quot;coloursR&quot;: 255, &quot;lat&quot;: 32.87788317, &quot;lng&quot;: -117.2372732, &quot;time_0&quot;: 61.077, &quot;time_100&quot;: 64.231, &quot;time_1000&quot;: 105.989, &quot;time_1015&quot;: 117.085, &quot;time_1030&quot;: 117.114, &quot;time_1045&quot;: 119.801, &quot;time_1100&quot;: 118.934, &quot;time_1115&quot;: 127.912, &quot;time_1130&quot;: 127.94, &quot;time_1145&quot;: 126.129, &quot;time_115&quot;: 64.796, &quot;time_1200&quot;: 124.29, &quot;time_1215&quot;: 117.788, &quot;time_1230&quot;: 116.586, &quot;time_1245&quot;: 119.093, &quot;time_130&quot;: 64.057, &quot;time_1300&quot;: 121.083, &quot;time_1315&quot;: 120.192, &quot;time_1330&quot;: 120.405, &quot;time_1345&quot;: 126.313, &quot;time_1400&quot;: 129.931, &quot;time_1415&quot;: 128.286, &quot;time_1430&quot;: 125.776, &quot;time_1445&quot;: 122.854, &quot;time_145&quot;: 63.748, &quot;time_15&quot;: 63.537